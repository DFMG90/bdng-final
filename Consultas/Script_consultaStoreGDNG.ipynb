# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (1.36.9)
# Requirement already satisfied: botocore<1.37.0,>=1.36.9 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from boto3) (1.36.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from boto3) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.37.0,>=1.36.9->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.37.0,>=1.36.9->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.37.0,>=1.36.9->boto3) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import boto3
 
# Especificar la región y las claves de acceso AWS
aws_region = 'eu-west-3'
aws_access_key_id = ''
aws_secret_access_key = ''
 
# Crear un cliente de DynamoDB con la región y claves especificadas
client = boto3.client(
    'dynamodb',
    region_name=aws_region,
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key
)
 
# Crear un recurso de DynamoDB con la región y claves especificadas
dynamodb = boto3.resource(
    'dynamodb',
    region_name=aws_region,
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key
)

# %%
import boto3
from collections import defaultdict
from boto3.dynamodb.conditions import Attr, Key

ordenes = dynamodb.Table('Ordenes')
productos = dynamodb.Table('productos')

# Realizamos un scan para obtener todos los ítems de la tabla de productos
response_productos = productos.scan()
items_productos = response_productos['Items']

# Realizamos un scan para obtener todos los ítems de la tabla de órdenes
response_ordenes = ordenes.scan()
items_ordenes = response_ordenes['Items']
 
# Verificamos los datos obtenidos
print("Productos obtenidos:")
print(items_productos)
print("Órdenes obtenidas:")
print(items_ordenes)
# Out:
# Productos obtenidos:
# [{'ProductID': 'BF1772', 'descripcion': 'jeans de color gris oscuro, doblados. Los jeans tienen un bolsillo trasero visible y una etiqueta en la pretina.', 'Producto': 'Pantalones Skinny Oscuro', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/panatalon2.JPG', 'precio': Decimal('41')}, {'ProductID': 'BF2152', 'descripcion': 'falda roja con flores subliminadas de talle alto y corta.', 'Producto': 'Falda Estampada Flores', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/falda2.JPG', 'precio': Decimal('28.49')}, {'ProductID': 'BF1681', 'descripcion': 'jeans de mezclilla azul con cintura alta y piernas anchas. Los jeans tienen dos grandes bolsillos frontales y un cierre de botón con cremallera.', 'Producto': 'Pantalones Bota Ancha', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/pantalon3.JPG', 'precio': Decimal('29.99')}, {'ProductID': 'BF2370', 'descripcion': 'Falda en jean con un bordado de flores  que añade un elemento decorativo y estiloso.\n', 'Producto': 'Falda Jean', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/falda1.JPG', 'precio': Decimal('24.99')}, {'ProductID': 'BF9289', 'descripcion': 'Vestido florecido con una combinacion de colores perfecta.', 'Producto': 'Vestido Flores', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/vestido3.JPG', 'precio': Decimal('49.99')}, {'ProductID': 'BF8238', 'descripcion': 'Camiseta en algodón con estampado de color con un contraste que crean una sinergia perfecta.', 'Producto': 'Camisa Estampada B/W', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/camisa+3.JPG', 'precio': Decimal('31')}, {'ProductID': 'BF0060', 'descripcion': 'La bufanda presenta un elegante diseño suave y ligera lo que la hace cómoda y adecuada para el uso diario. Perfecta para darle un toque de estilo a cualquier atuendo.', 'Producto': 'Bufanda Rayas', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/bufanda2.JPG', 'precio': Decimal('28.7')}, {'ProductID': 'BF9878', 'descripcion': 'Zapatos tipo tenis blancos con cordones anchos comodos y versatiles.', 'Producto': 'Zapatos Altos Blancos', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/zapatos2.JPG', 'precio': Decimal('65.49')}, {'ProductID': 'BF0809', 'descripcion': 'zapatos con una combinacion de colores perfecta y comodos para el dia a dia.', 'Producto': 'Zapatos Multicolor', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/zapatos3.JPG', 'precio': Decimal('45.99')}, {'ProductID': 'BF7814', 'descripcion': 'Gafas con una montura transparente o de color claro. Las gafas tienen una forma clásica, ligeramente cuadrada y redondeada.', 'Producto': 'Gafas Transparentes', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/gafas1.JPG', 'precio': Decimal('34.5')}, {'ProductID': 'BF8063', 'descripcion': 'Vestido rojo con puntos blancos con un estilo clasico pero juvenil a su vez.', 'Producto': 'Vestido Rojo Estampado', 'categoria': 'Prenda', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/vestido1.JPG', 'precio': Decimal('51.99')}, {'ProductID': 'BF6885', 'descripcion': 'gafas de sol redondas con lentes de color rosa. La montura es metálica, con un puente y patillas delgadas. Las lentes rosas le dan a las gafas un aspecto elegante y moderno.', 'Producto': 'Gafas Rosados', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/gafas3.JPG', 'precio': Decimal('26')}, {'ProductID': 'BF5238', 'descripcion': 'Collar tipo choker atrevido y perfecto para complementar tu estilo.', 'Producto': 'Collar Choker', 'categoria': 'Accesorio', 'urls3': 'https://productosizzyshop.s3.us-east-1.amazonaws.com/collar3.JPG', 'precio': Decimal('40.9')}, {'ProductID':  ...
# Órdenes obtenidas:
# [{'ProductID': 'BF2370', 'Review': 'Exquisite craftsmanship here is absolutely appreciated.', 'ClientID': '601355057', 'BuyerAge': Decimal('29'), 'OrderDate': '7/03/2024', 'ShippingCharges': Decimal('100'), 'Quantity': Decimal('1'), 'BuyerGender': 'Female', 'InternationalShipping': 'Yes', 'OrderID': '163287', 'SalesPrice': Decimal('15'), 'Email': 'edemeadaa@skyrock.com', 'TotalSales': Decimal('115'), 'SalesPerUnit': Decimal('115'), 'NameClient': 'Eachelle Demead', 'OrderLocation': 'Sydney', 'Rating': Decimal('4')}, {'ProductID': 'BF1414', 'Review': 'Waste of Money.', 'ClientID': '190499590', 'BuyerAge': Decimal('24'), 'OrderDate': '21/09/2024', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('5'), 'BuyerGender': 'Male', 'InternationalShipping': 'No', 'OrderID': '174970', 'SalesPrice': Decimal('65'), 'Email': 'clivesleyix@hexun.com', 'TotalSales': Decimal('325'), 'SalesPerUnit': Decimal('65'), 'NameClient': 'Cass Livesley', 'OrderLocation': 'Detroit', 'Rating': Decimal('1')}, {'ProductID': 'BF8063', 'Review': 'The product was affordable here compared to other brands.', 'ClientID': '679633181', 'BuyerAge': Decimal('18'), 'OrderDate': '6/02/2024', 'ShippingCharges': Decimal('40'), 'Quantity': Decimal('1'), 'BuyerGender': 'Male', 'InternationalShipping': 'Yes', 'OrderID': '177823', 'SalesPrice': Decimal('130'), 'Email': 'vbrumenhn@merriam-webster.com', 'TotalSales': Decimal('170'), 'SalesPerUnit': Decimal('170'), 'NameClient': 'Van Brumen', 'OrderLocation': 'Cardiff', 'Rating': Decimal('4')}, {'ProductID': 'BF1681', 'Review': 'The Product exhibits good design.', 'ClientID': '153154348', 'BuyerAge': Decimal('20'), 'OrderDate': '30/12/2023', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('2'), 'BuyerGender': 'Female', 'InternationalShipping': 'No', 'OrderID': '182201', 'SalesPrice': Decimal('65'), 'Email': 'anemchinov69@blinklist.com', 'TotalSales': Decimal('130'), 'SalesPerUnit': Decimal('65'), 'NameClient': 'Adrian Nemchinov', 'OrderLocation': 'New Jersey', 'Rating': Decimal('4')}, {'ProductID': 'BF0103', 'Review': 'There is clear evidence of subpar detailing.', 'ClientID': '220575020', 'BuyerAge': Decimal('21'), 'OrderDate': '24/09/2024', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('1'), 'BuyerGender': 'Male', 'InternationalShipping': 'No', 'OrderID': '146245', 'SalesPrice': Decimal('65'), 'Email': 'lrolfi79@soundcloud.com', 'TotalSales': Decimal('65'), 'SalesPerUnit': Decimal('65'), 'NameClient': 'Laina Rolfi', 'OrderLocation': 'Sacramento', 'Rating': Decimal('1')}, {'ProductID': 'BF9289', 'Review': 'Not as expected.', 'ClientID': '612161326', 'BuyerAge': Decimal('32'), 'OrderDate': '23/11/2023', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('1'), 'BuyerGender': 'Male', 'InternationalShipping': 'No', 'OrderID': '121322', 'SalesPrice': Decimal('20'), 'Email': 'pkinnochgm@istockphoto.com', 'TotalSales': Decimal('20'), 'SalesPerUnit': Decimal('20'), 'NameClient': 'Piotr Kinnoch', 'OrderLocation': 'Portland', 'Rating': Decimal('3')}, {'ProductID': 'BF8063', 'Review': 'Exquisite craftsmanship here is absolutely appreciated.', 'ClientID': '464759072', 'BuyerAge': Decimal('31'), 'OrderDate': '9/10/2024', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('1'), 'BuyerGender': 'Female', 'InternationalShipping': 'No', 'OrderID': '171114', 'SalesPrice': Decimal('65'), 'Email': 'rrayhillcj@pinterest.com', 'TotalSales': Decimal('65'), 'SalesPerUnit': Decimal('65'), 'NameClient': 'Romola Rayhill', 'OrderLocation': 'New York', 'Rating': Decimal('5')}, {'ProductID': 'BF8238', 'Review': 'Careless handling by the delivery team.', 'ClientID': '824847749', 'BuyerAge': Decimal('23'), 'OrderDate': '30/01/2024', 'ShippingCharges': Decimal('0'), 'Quantity': Decimal('1'), 'BuyerGender': 'Male', 'InternationalShipping': 'No', 'OrderID': '137723', 'SalesPrice': Decimal('15'), 'Email': 'adwanel@virginia.edu', 'TotalSales': Decimal('15'), 'SalesPerUnit': Decimal('15'), 'NameClient': 'Adele Dwane', 'OrderLocation': 'Miami', 'Rati ...

# %%
import decimal
if items_ordenes:
    seen_product_ids = set()
    
    highest_rated_products = []
    for item in items_ordenes:
        if item['Rating'] == decimal.Decimal('5') and item['ProductID'] not in seen_product_ids:
            highest_rated_products.append(item)
            seen_product_ids.add(item['ProductID'])

    print(" Productos con mayor rating:")
    if highest_rated_products:
        for product in highest_rated_products:
            print(f" ProductID: {product['ProductID']}")
            print(f" Rating: {product['Rating']}")
            print(f" Nombre del Cliente: {product['NameClient']}")
            print(f" OrderID: {product['OrderID']}")
            print("----")
    else:
        print("No hay productos con rating 5.")
else:
    print("No hay productos en la tabla.")
# Out:
#  Productos con mayor rating:
#  ProductID: BF8063
#  Rating: 5
#  Nombre del Cliente: Romola Rayhill
#  OrderID: 171114
# ----
#  ProductID: BF9289
#  Rating: 5
#  Nombre del Cliente: Cecil Garz
#  OrderID: 141520
# ----
#  ProductID: BF2370
#  Rating: 5
#  Nombre del Cliente: Geoffrey Brass
#  OrderID: 189128
# ----
#  ProductID: BF2152
#  Rating: 5
#  Nombre del Cliente: Bernhard Hamp
#  OrderID: 186391
# ----
#  ProductID: BF1681
#  Rating: 5
#  Nombre del Cliente: Matthew Kleinmann
#  OrderID: 124594
# ----
#  ProductID: BF6975
#  Rating: 5
#  Nombre del Cliente: Thor Spatoni
#  OrderID: 175103
# ----
#  ProductID: BF7814
#  Rating: 5
#  Nombre del Cliente: Clemens O'Farris
#  OrderID: 167556
# ----
#  ProductID: BF0060
#  Rating: 5
#  Nombre del Cliente: Kamila Gatcliff
#  OrderID: 125263
# ----
#  ProductID: BF6604
#  Rating: 5
#  Nombre del Cliente: Lonnard Pitbladdo
#  OrderID: 158706
# ----
#  ProductID: BF6693
#  Rating: 5
#  Nombre del Cliente: Dew Johannes
#  OrderID: 126824
# ----
#  ProductID: BF9878
#  Rating: 5
#  Nombre del Cliente: Cozmo O'Hanlon
#  OrderID: 173498
# ----
#  ProductID: BF1414
#  Rating: 5
#  Nombre del Cliente: Tanitansy Gerrie
#  OrderID: 193770
# ----
#  ProductID: BF6167
#  Rating: 5
#  Nombre del Cliente: Abbi Salvidge
#  OrderID: 169762
# ----
#  ProductID: BF9724
#  Rating: 5
#  Nombre del Cliente: Fletch Schneidau
#  OrderID: 128820
# ----
#  ProductID: BF9708
#  Rating: 5
#  Nombre del Cliente: Risa Salasar
#  OrderID: 184870
# ----
#  ProductID: BF1772
#  Rating: 5
#  Nombre del Cliente: Bev Mulcahy
#  OrderID: 120784
# ----
#  ProductID: BF3942
#  Rating: 5
#  Nombre del Cliente: Esmeralda Zettler
#  OrderID: 136437
# ----
#  ProductID: BF4831
#  Rating: 5
#  Nombre del Cliente: Granthem Rainton
#  OrderID: 139515
# ----
#  ProductID: BF8238
#  Rating: 5
#  Nombre del Cliente: Tatiana Falkous
#  OrderID: 125203
# ----
#  ProductID: BF5238
#  Rating: 5
#  Nombre del Cliente: Pincus Croughan
#  OrderID: 124791
# ----
#  ProductID: BF0809
#  Rating: 5
#  Nombre del Cliente: Erin Flageul
#  OrderID: 136047
# ----
#  ProductID: BF2887
#  Rating: 5
#  Nombre del Cliente: Aldo Beekmann
#  OrderID: 165945
# ----
#  ProductID: BF6885
#  Rating: 5
#  Nombre del Cliente: Bibbie Bundy
#  OrderID: 150648
# ----
#  ProductID: BF0103
#  Rating: 5
#  Nombre del Cliente: Esmeralda Game
#  OrderID: 142964
# ----

# %%
import decimal
if items_ordenes:
 
    seen_product_ids = set()
    
    highest_rated_products = []
    for item in items_ordenes:
        if item['Rating'] == decimal.Decimal('1') and item['ProductID'] not in seen_product_ids:
            highest_rated_products.append(item)
            seen_product_ids.add(item['ProductID'])

    print(" Productos con mayor rating:")
    if highest_rated_products:
        for product in highest_rated_products:
            print(f" ProductID: {product['ProductID']}")
            print(f" Rating: {product['Rating']}")
            print(f" Nombre del Cliente: {product['NameClient']}")
            print(f" OrderID: {product['OrderID']}")
            print("----")
    else:
        print("No hay productos con rating 1.")
else:
    print("No hay productos en la tabla.")
# Out:
#  Productos con mayor rating:
#  ProductID: BF1414
#  Rating: 1
#  Nombre del Cliente: Cass Livesley
#  OrderID: 174970
# ----
#  ProductID: BF0103
#  Rating: 1
#  Nombre del Cliente: Laina Rolfi
#  OrderID: 146245
# ----
#  ProductID: BF8238
#  Rating: 1
#  Nombre del Cliente: Adele Dwane
#  OrderID: 137723
# ----
#  ProductID: BF1681
#  Rating: 1
#  Nombre del Cliente: Kelsey Jagger
#  OrderID: 168762
# ----
#  ProductID: BF6693
#  Rating: 1
#  Nombre del Cliente: Carlyle Petrashkov
#  OrderID: 185320
# ----
#  ProductID: BF6975
#  Rating: 1
#  Nombre del Cliente: Karlik Benedetti
#  OrderID: 125165
# ----
#  ProductID: BF6604
#  Rating: 1
#  Nombre del Cliente: Hildegaard Yurlov
#  OrderID: 126948
# ----
#  ProductID: BF9878
#  Rating: 1
#  Nombre del Cliente: Saundra Capper
#  OrderID: 165536
# ----
#  ProductID: BF0060
#  Rating: 1
#  Nombre del Cliente: Kelli Martschke
#  OrderID: 169656
# ----
#  ProductID: BF9724
#  Rating: 1
#  Nombre del Cliente: Ricky Virr
#  OrderID: 125379
# ----
#  ProductID: BF3942
#  Rating: 1
#  Nombre del Cliente: Russ Kuschek
#  OrderID: 145296
# ----
#  ProductID: BF5238
#  Rating: 1
#  Nombre del Cliente: Noelle Kusick
#  OrderID: 139185
# ----
#  ProductID: BF9708
#  Rating: 1
#  Nombre del Cliente: Julienne France
#  OrderID: 187055
# ----
#  ProductID: BF0809
#  Rating: 1
#  Nombre del Cliente: Pen Ferreras
#  OrderID: 145866
# ----
#  ProductID: BF2370
#  Rating: 1
#  Nombre del Cliente: Inness Konzel
#  OrderID: 126716
# ----
#  ProductID: BF2152
#  Rating: 1
#  Nombre del Cliente: Kirstyn Giraudeau
#  OrderID: 166222
# ----
#  ProductID: BF7814
#  Rating: 1
#  Nombre del Cliente: Maighdiln Hensmans
#  OrderID: 172838
# ----
#  ProductID: BF1772
#  Rating: 1
#  Nombre del Cliente: Saba Skryne
#  OrderID: 130466
# ----
#  ProductID: BF2887
#  Rating: 1
#  Nombre del Cliente: Nels Bollini
#  OrderID: 125549
# ----
#  ProductID: BF6167
#  Rating: 1
#  Nombre del Cliente: Norene Abson
#  OrderID: 168861
# ----
#  ProductID: BF4831
#  Rating: 1
#  Nombre del Cliente: Burt Hanniger
#  OrderID: 133941
# ----
#  ProductID: BF9289
#  Rating: 1
#  Nombre del Cliente: Heda Donnersberg
#  OrderID: 141610
# ----
#  ProductID: BF6885
#  Rating: 1
#  Nombre del Cliente: Zarah Cozby
#  OrderID: 184338
# ----
#  ProductID: BF8063
#  Rating: 1
#  Nombre del Cliente: Hersh Hugonin
#  OrderID: 162482
# ----

# %%
# Ventas por ubicación
# Consulta: Obtener las ventas totales por ubicación (ciudad, región, etc.).
# Objetivo: Identificar qué áreas geográficas están generando más ventas.

# %%
from collections import defaultdict

sales_by_location = defaultdict(int)

for item in items_ordenes:
    if 'OrderLocation' in item and 'Quantity' in item:
        location = item['OrderLocation']
        quantity = int(item['Quantity']) 
        sales_by_location[location] += quantity

sorted_sales_by_location = sorted(sales_by_location.items(), key=lambda x: x[1], reverse=True)

print(" Cantidad de ventas por lugar :")
for location, total_sales in sorted_sales_by_location:
    print(f" {location}: {total_sales} ventas")
# Out:
#  Cantidad de ventas por lugar :
#  San Francisco: 352 ventas
#  Sacramento: 345 ventas
#  Las Vegas: 335 ventas
#  New York: 322 ventas
#  Cleveland: 316 ventas
#  Portland: 312 ventas
#  New Jersey: 306 ventas
#  San Antonio: 300 ventas
#  Pittsburgh: 298 ventas
#  Memphis: 286 ventas
#  Austin: 283 ventas
#  Detroit: 279 ventas
#  Miami: 266 ventas
#  London: 163 ventas
#  Montreal: 161 ventas
#  Dublin: 156 ventas
#  Manchester: 155 ventas
#  Liverpool: 150 ventas
#  Mumbai: 148 ventas
#  Cardiff: 147 ventas
#  Paris: 147 ventas
#  Sydney: 140 ventas
#  Glasgow: 135 ventas
#  Toronto: 133 ventas
#  New Delhi: 130 ventas

# %%
# Ventas por categoría de producto
# Consulta: Obtener el total de ventas por categoría (por ejemplo, 'Prenda', 'Electrónica', etc.).
# Objetivo: Determinar qué categorías de productos son más populares y contribuyen más a las ventas.

# %%
category_sales = defaultdict(int)

for item_orden in items_ordenes:
    if 'ProductID' in item_orden and 'Quantity' in item_orden:
        product_id = item_orden['ProductID']
        quantity = int(item_orden['Quantity'])

        product_info = next((prod for prod in items_productos if prod.get('ProductID') == product_id), None)

        if product_info:
            category = product_info.get('categoria', 'Desconocida')

            category_sales[category] += quantity
        else:
            print(f"Producto con ProductID {product_id} no encontrado en la lista de productos.")

sorted_category_sales = sorted(category_sales.items(), key=lambda x: x[1], reverse=True)

print(" Ventas por categoría de producto:")
for category, total_sales in sorted_category_sales:
    print(f" Categoría: {category} - Total Ventas: {total_sales}")
# Out:
#  Ventas por categoría de producto:
#  Categoría: Prenda - Total Ventas: 2912
#  Categoría: Accesorio - Total Ventas: 2853

# %%
# Promedio de ventas por cliente
# Consulta: Obtener el promedio de ventas por cliente.
# Objetivo: Evaluar el comportamiento de los clientes y su nivel de gasto promedio.

# %%
from collections import defaultdict

customer_sales = defaultdict(int)

for item in items_ordenes:
    if 'ClientID' in item and 'TotalSales' in item:
        client_id = item['ClientID']
        customer_sales[client_id] += float(item['TotalSales'])

total_customers = len(customer_sales)
total_sales = sum(customer_sales.values())
avg_sales_per_customer = total_sales / total_customers if total_customers else 0

print(f" Promedio de ventas por cliente: {avg_sales_per_customer:.2f}")
# Out:
#  Promedio de ventas por cliente: 576.01

# %%
# Porcentaje de productos con calificación alta (Rating >= 4)
# Consulta: Obtener el porcentaje de productos con una calificación de 4 o más.
# Objetivo: Medir la satisfacción general de los clientes y el rendimiento de los productos.

# %%
import decimal

high_rated_count = 0
total_products = len(items_ordenes)

for item in items_ordenes:
    if 'Rating' in item and float(item['Rating']) >= 4:  # Acceder directamente a 'Rating'
        high_rated_count += 1

high_rating_percentage = (high_rated_count / total_products) * 100 if total_products else 0

print(f"Porcentaje de productos con rating 4 o más: {high_rating_percentage:.2f}%")
# Out:
# Porcentaje de productos con rating 4 o más: 60.48%

# %%
# Ventas por cantidad de productos
# Consulta: Obtener el total de ventas por cantidad de productos vendidos.
# Objetivo: Saber qué tan rápido se venden los productos en comparación con otros.

# %%
from collections import defaultdict

product_quantity_sales = defaultdict(int)

for item in items_ordenes:
    if 'ProductID' in item and 'Quantity' in item:
        product_id = item['ProductID']
        product_quantity_sales[product_id] += int(item['Quantity'])

print("Ventas por cantidad de productos:")
for product_id, quantity in product_quantity_sales.items():
    print(f"Producto {product_id}: {quantity} unidades vendidas")
# Out:
# Ventas por cantidad de productos:
# Producto BF2370: 234 unidades vendidas
# Producto BF1414: 264 unidades vendidas
# Producto BF8063: 261 unidades vendidas
# Producto BF1681: 249 unidades vendidas
# Producto BF0103: 230 unidades vendidas
# Producto BF9289: 260 unidades vendidas
# Producto BF8238: 256 unidades vendidas
# Producto BF6693: 236 unidades vendidas
# Producto BF2887: 226 unidades vendidas
# Producto BF6975: 252 unidades vendidas
# Producto BF2152: 206 unidades vendidas
# Producto BF9878: 274 unidades vendidas
# Producto BF0060: 257 unidades vendidas
# Producto BF6167: 244 unidades vendidas
# Producto BF3942: 238 unidades vendidas
# Producto BF7814: 261 unidades vendidas
# Producto BF5238: 231 unidades vendidas
# Producto BF9724: 270 unidades vendidas
# Producto BF0809: 197 unidades vendidas
# Producto BF6604: 235 unidades vendidas
# Producto BF1772: 260 unidades vendidas
# Producto BF6885: 222 unidades vendidas
# Producto BF4831: 170 unidades vendidas
# Producto BF9708: 232 unidades vendidas

# %%
# Análisis de ventas por género del comprador
# Consulta: Obtener las ventas totales por género de los compradores.
# Objetivo: Analizar las diferencias en las preferencias de compra según el género

# %%
import decimal
from collections import defaultdict

gender_sales = defaultdict(int)

for item in items_ordenes:
    if 'BuyerGender' in item and 'TotalSales' in item:
        # 'TotalSales' ya es un Decimal, lo convertimos directamente a float
        gender_sales[item['BuyerGender']] += float(item['TotalSales'])

print(" Ventas por género del comprador:")
for gender, total_sales in gender_sales.items():
    print(f" Género: {gender} - Ventas Totales: {total_sales}")
# Out:
#  Ventas por género del comprador:
#  Género: Female - Ventas Totales: 113590.0
#  Género: Male - Ventas Totales: 287311.0

# %%
# Análisis de ventas por fecha (últimos 100 días, por ejemplo)
# Consulta: Obtener las ventas realizadas en los últimos 30 días, mostrando el total de ventas por día.
# Objetivo: Analizar el comportamiento de ventas y detectar tendencias o patrones estacionales.

# %%
from datetime import datetime, timedelta
from collections import defaultdict

today = datetime.today()
thirty_days_ago = today - timedelta(days=100)

daily_sales = defaultdict(float)

for item in items_ordenes:
    if 'OrderDate' in item and 'TotalSales' in item:
        order_date = datetime.strptime(item['OrderDate'], '%d/%m/%Y')
        if order_date >= thirty_days_ago:
            daily_sales[order_date.date()] += float(item['TotalSales'])

sorted_daily_sales = sorted(daily_sales.items(), key=lambda x: x[0])

print(" Ventas por fecha en los últimos 30 días:")
for date, total_sales in sorted_daily_sales:
    print(f" Fecha: {date} - Ventas Totales: {total_sales}")
# Out:
#  Ventas por fecha en los últimos 30 días:
#  Fecha: 2024-10-23 - Ventas Totales: 354.0
#  Fecha: 2024-10-24 - Ventas Totales: 959.0
#  Fecha: 2024-10-25 - Ventas Totales: 750.0
#  Fecha: 2024-10-26 - Ventas Totales: 999.0
#  Fecha: 2024-10-27 - Ventas Totales: 739.0
#  Fecha: 2024-10-28 - Ventas Totales: 612.0
#  Fecha: 2024-10-29 - Ventas Totales: 573.0
#  Fecha: 2024-10-30 - Ventas Totales: 1384.0
#  Fecha: 2024-10-31 - Ventas Totales: 1353.0
#  Fecha: 2024-11-01 - Ventas Totales: 2133.0
#  Fecha: 2024-11-02 - Ventas Totales: 463.0
#  Fecha: 2024-11-03 - Ventas Totales: 1314.0
#  Fecha: 2024-11-04 - Ventas Totales: 523.0

# %%
# Promedio de ventas por ubicación y categoría
# Consulta: Obtener el promedio de ventas por ubicación y categoría de producto.
# Objetivo: Analizar qué combinaciones de ubicación y categoría generan más ventas en promedio.

# %%
location_category_sales = defaultdict(lambda: defaultdict(float))
location_category_count = defaultdict(lambda: defaultdict(int))

for item in items_ordenes:
    if 'OrderLocation' in item and 'ProductID' in item and 'TotalSales' in item:
        location = item['OrderLocation']
        product_id = item['ProductID']  
        
        product_info = next((prod for prod in items_productos if prod['ProductID'] == product_id), None) 
        if product_info:
            category = product_info['categoria']  # Ya no usamos ['S']
            location_category_sales[location][category] += float(item['TotalSales'])
            location_category_count[location][category] += 1

for location in location_category_sales:
    for category in location_category_sales[location]:
        total_sales = location_category_sales[location][category]
        total_count = location_category_count[location][category]
        avg_sales = total_sales / total_count if total_count else 0
        print(f" Ubicación: {location}, Categoría: {category} - Promedio de Ventas: {avg_sales:.2f}")
# Out:
#  Ubicación: Sydney, Categoría: Prenda - Promedio de Ventas: 251.21
#  Ubicación: Sydney, Categoría: Accesorio - Promedio de Ventas: 276.04
#  Ubicación: Detroit, Categoría: Prenda - Promedio de Ventas: 92.08
#  Ubicación: Detroit, Categoría: Accesorio - Promedio de Ventas: 105.46
#  Ubicación: Cardiff, Categoría: Prenda - Promedio de Ventas: 145.80
#  Ubicación: Cardiff, Categoría: Accesorio - Promedio de Ventas: 168.33
#  Ubicación: New Jersey, Categoría: Prenda - Promedio de Ventas: 83.75
#  Ubicación: New Jersey, Categoría: Accesorio - Promedio de Ventas: 94.87
#  Ubicación: Sacramento, Categoría: Prenda - Promedio de Ventas: 96.89
#  Ubicación: Sacramento, Categoría: Accesorio - Promedio de Ventas: 84.01
#  Ubicación: Portland, Categoría: Prenda - Promedio de Ventas: 85.86
#  Ubicación: Portland, Categoría: Accesorio - Promedio de Ventas: 87.86
#  Ubicación: New York, Categoría: Prenda - Promedio de Ventas: 94.07
#  Ubicación: New York, Categoría: Accesorio - Promedio de Ventas: 85.04
#  Ubicación: Miami, Categoría: Prenda - Promedio de Ventas: 73.99
#  Ubicación: Miami, Categoría: Accesorio - Promedio de Ventas: 90.64
#  Ubicación: Liverpool, Categoría: Accesorio - Promedio de Ventas: 167.20
#  Ubicación: Liverpool, Categoría: Prenda - Promedio de Ventas: 162.38
#  Ubicación: Mumbai, Categoría: Prenda - Promedio de Ventas: 244.28
#  Ubicación: Mumbai, Categoría: Accesorio - Promedio de Ventas: 181.42
#  Ubicación: Montreal, Categoría: Prenda - Promedio de Ventas: 124.49
#  Ubicación: Montreal, Categoría: Accesorio - Promedio de Ventas: 156.98
#  Ubicación: London, Categoría: Prenda - Promedio de Ventas: 180.37
#  Ubicación: London, Categoría: Accesorio - Promedio de Ventas: 143.75
#  Ubicación: San Antonio, Categoría: Accesorio - Promedio de Ventas: 99.69
#  Ubicación: San Antonio, Categoría: Prenda - Promedio de Ventas: 74.90
#  Ubicación: San Francisco, Categoría: Accesorio - Promedio de Ventas: 89.73
#  Ubicación: San Francisco, Categoría: Prenda - Promedio de Ventas: 94.59
#  Ubicación: Cleveland, Categoría: Accesorio - Promedio de Ventas: 97.64
#  Ubicación: Cleveland, Categoría: Prenda - Promedio de Ventas: 76.76
#  Ubicación: Austin, Categoría: Prenda - Promedio de Ventas: 100.47
#  Ubicación: Austin, Categoría: Accesorio - Promedio de Ventas: 79.35
#  Ubicación: Dublin, Categoría: Accesorio - Promedio de Ventas: 151.91
#  Ubicación: Dublin, Categoría: Prenda - Promedio de Ventas: 143.20
#  Ubicación: Paris, Categoría: Accesorio - Promedio de Ventas: 173.63
#  Ubicación: Paris, Categoría: Prenda - Promedio de Ventas: 155.86
#  Ubicación: Glasgow, Categoría: Accesorio - Promedio de Ventas: 151.92
#  Ubicación: Glasgow, Categoría: Prenda - Promedio de Ventas: 182.43
#  Ubicación: Las Vegas, Categoría: Prenda - Promedio de Ventas: 103.94
#  Ubicación: Las Vegas, Categoría: Accesorio - Promedio de Ventas: 81.86
#  Ubicación: Memphis, Categoría: Accesorio - Promedio de Ventas: 107.38
#  Ubicación: Memphis, Categoría: Prenda - Promedio de Ventas: 82.17
#  Ubicación: Toronto, Categoría: Accesorio - Promedio de Ventas: 154.35
#  Ubicación: Toronto, Categoría: Prenda - Promedio de Ventas: 160.18
#  Ubicación: New Delhi, Categoría: Prenda - Promedio de Ventas: 169.36
#  Ubicación: New Delhi, Categoría: Accesorio - Promedio de Ventas: 268.42
#  Ubicación: Pittsburgh, Categoría: Accesorio - Promedio de Ventas: 93.19
#  Ubicación: Pittsburgh, Categoría: Prenda - Promedio de Ventas: 99.72
#  Ubicación: Manchester, Categoría: Accesorio - Promedio de Ventas: 135.27
#  Ubicación: Manchester, Categoría: Prenda - Promedio de Ventas: 178.00

# %%
# Productos con mayor ingreso total
# Consulta: Obtener los productos que generaron más ingresos en total.
# Objetivo: Identificar qué productos están generando los mayores ingresos y ajustar estrategias de marketing o inventario.

# %%
import decimal
product_revenue = defaultdict(float)

for item in items_ordenes:
    if 'ProductID' in item and 'TotalSales' in item and 'Quantity' in item:
        product_id = item['ProductID']  
        revenue = float(item['TotalSales'])  
        product_revenue[product_id] += revenue

sorted_product_revenue = sorted(product_revenue.items(), key=lambda x: x[1], reverse=True)

print(" Productos con mayor ingreso total:")
for product_id, total_revenue in sorted_product_revenue:
    print(f" ProductoID: {product_id} - Ingreso Total: {total_revenue:.2f}")
# Out:
#  Productos con mayor ingreso total:
#  ProductoID: BF9878 - Ingreso Total: 20009.00
#  ProductoID: BF1772 - Ingreso Total: 19514.00
#  ProductoID: BF9289 - Ingreso Total: 19055.00
#  ProductoID: BF9724 - Ingreso Total: 18790.00
#  ProductoID: BF1414 - Ingreso Total: 18665.00
#  ProductoID: BF6167 - Ingreso Total: 18636.00
#  ProductoID: BF6604 - Ingreso Total: 18315.00
#  ProductoID: BF7814 - Ingreso Total: 18083.00
#  ProductoID: BF1681 - Ingreso Total: 18041.00
#  ProductoID: BF0060 - Ingreso Total: 17611.00
#  ProductoID: BF8063 - Ingreso Total: 17303.00
#  ProductoID: BF3942 - Ingreso Total: 17243.00
#  ProductoID: BF6693 - Ingreso Total: 17173.00
#  ProductoID: BF8238 - Ingreso Total: 16870.00
#  ProductoID: BF5238 - Ingreso Total: 15927.00
#  ProductoID: BF6975 - Ingreso Total: 15771.00
#  ProductoID: BF2887 - Ingreso Total: 15647.00
#  ProductoID: BF9708 - Ingreso Total: 14962.00
#  ProductoID: BF2370 - Ingreso Total: 14945.00
#  ProductoID: BF2152 - Ingreso Total: 14706.00
#  ProductoID: BF6885 - Ingreso Total: 14402.00
#  ProductoID: BF0103 - Ingreso Total: 14217.00
#  ProductoID: BF0809 - Ingreso Total: 13553.00
#  ProductoID: BF4831 - Ingreso Total: 11463.00

# %%
# Ventas según el canal de envío (nacional vs internacional)
# Consulta: Obtener las ventas totales según el tipo de envío (nacional o internacional).
# Objetivo: Evaluar si los envíos internacionales están generando un porcentaje significativo de las ventas.

# %%
shipping_sales = defaultdict(float)

for item in items_ordenes:
    if 'InternationalShipping' in item and 'TotalSales' in item:
        shipping_type = item['InternationalShipping']
        

        if shipping_type == 'Yes':
            shipping_type = 'Internacional'
        elif shipping_type == 'No':
            shipping_type = 'Nacional'
        
        shipping_sales[shipping_type] += float(item['TotalSales'])

print(" Ventas por tipo de envío:")
for shipping_type, total_sales in shipping_sales.items():
    print(f" Envío {shipping_type}: Ventas Totales: {total_sales:.2f}")
# Out:
#  Ventas por tipo de envío:
#  Envío Internacional: Ventas Totales: 182155.00
#  Envío Nacional: Ventas Totales: 218746.00

# %%
# Clientes recurrentes
# Consulta: Obtener la cantidad de clientes recurrentes (que han hecho más de 10 compras).
# Objetivo: Identificar cuántos clientes están regresando y la fidelidad de la base de clientes.

# %%
from collections import defaultdict

clientes_compras = defaultdict(int)
clientes_nombres = {}

for item in items_ordenes:
    if 'ClientID' in item and 'NameClient' in item:
        clientes_compras[item['ClientID']] += 1
        clientes_nombres[item['ClientID']] = item['NameClient'] 

clientes_recurrentes = {cliente: compras for cliente, compras in clientes_compras.items() if compras > 10}
cantidad_recurrentes = len(clientes_recurrentes)

print(f" Clientes Recurrentes: {cantidad_recurrentes}")
for cliente, compras in clientes_recurrentes.items():
    nombre_cliente = clientes_nombres.get(cliente, "Desconocido")  # Obtener el nombre o mostrar "Desconocido" si falta
    print(f" Cliente: {nombre_cliente} - Compras Realizadas: {compras}")
# Out:
#  Clientes Recurrentes: 10
#  Cliente: Adele Dwane - Compras Realizadas: 12
#  Cliente: Christine Jacquest - Compras Realizadas: 12
#  Cliente: Jacklyn Rudall - Compras Realizadas: 13
#  Cliente: Stevena Guillain - Compras Realizadas: 12
#  Cliente: Bonni Bliven - Compras Realizadas: 11
#  Cliente: Erin Flageul - Compras Realizadas: 12
#  Cliente: Bret Whyler - Compras Realizadas: 11
#  Cliente: Serge Stevani - Compras Realizadas: 11
#  Cliente: Mattias Hassin - Compras Realizadas: 11
#  Cliente: Clarette Jerred - Compras Realizadas: 11
